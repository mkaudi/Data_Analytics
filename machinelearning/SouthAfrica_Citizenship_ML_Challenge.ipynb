# %% [markdown]
# # Citizenship ML Challenge
#
#
# <img src="https://th.bing.com/th?id=OIP.K4XfRyYNnlwsR9-qdE-lrQHaE7&w=306&h=204&c=8&rs=1&qlt=90&o=6&dpr=1.5&pid=3.1&rm=2" width="30%" height="30%">

# %% [markdown]
# # Problem Statement
#
# The problem we are trying to solve is to predict whether or not a VodaPay customer will be active in the next month.
# VodaPay is Vodacom's e-commerce and financial services super-app

# %% [markdown]
# # Data Sources
# - ## Input data set (4 months period (October 2022- January 2023))
#    - Adobe Analytics Activity Features
#    - Transaction Features
#
# - ## Target definition
#    - Is the customer "active" or "inactive" based on their Adobe Analytics activiy
#
# - ## Data dictionary
#    - The features and the descriptions contained herein are as follows:
#
# <table>
# <thead>
# <tr>
# <th>Feature Name</th>
# <th>Feature Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>target</td>
# <td> The column to predict</td>
# </tr>
#
# <tr>
# <td>hashed_user_id</td>
# <td> Hashed unique identifier</td>
# </tr>
#
# <tr>
# <td>regist_date</td>
# <td> Date the user registered with VodaPay</td>
# </tr>
#
# <tr>
# <td>is_bind_card</td>
# <td> Do they have a debit/credit card linked</td>
# </tr>
#
# <tr>
# <td>lastorder_usecase</td>
# <td> The last transaction classification</td>
# </tr>
#
# <tr>
# <td>lastorder_platform</td>
# <td> The last transaction platform</td>
# </tr>
#
# <tr>
# <td>lastorder_orderdate</td>
# <td> The last transaction date</td>
# </tr>
#
# <tr>
# <td>subtotal_amount_today_daily</td>
# <td> The subtotal in transaction value for the last day of the month</td>
# </tr>
#
# <tr>
# <td>subtotal_amount_recent_7days</td>
# <td> The subtotal in transaction value for the last 7 days of the month</td>
# </tr>
#
# <tr>
# <td>subtotal_amount_recent_30days</td>
# <td> The subtotal in transaction value for the last 30 days of the month</td>
# </tr>
#
# <tr>
# <td>subtotal_ordercount_today_daily</td>
# <td> The subtotal number of transactions for the last day of the month</td>
# </tr>
#
# <tr>
# <td>subtotal_ordercount_recent_7days</td>
# <td> The subtotal number of transactions for the last 7 days of the month</td>
# </tr>
#
# <tr>
# <td>subtotal_ordercount_recent_30days</td>
# <td> The subtotal number of transactions for the last 30 days of the month</td>
# </tr>
#
# <tr>
# <td>nr_interactions</td>
# <td> The number of in-app clicks and interactions</td>
# </tr>
#
# <tr>
# <td>nr_days_interacted</td>
# <td> The number of unique days engaging with the app</td>
# </tr>
#
# <tr>
# <td>max_date_time</td>
# <td> The last active day in the current month</td>
# </tr>
#
# <tr>
# <td>nr_unique_pages_visited</td>
# <td> The number of unique page visits</td>
# </tr>
#
# <tr>
# <td>search_events</td>
# <td> The number of events searching for mini-apps</td>
# </tr>
#
# <tr>
# <td>unique_search_terms</td>
# <td> The number of unique search terms used</td>
# </tr>
#
# <tr>
# <td>unique_app_visits</td>
# <td> The number of unique mini-apps visited</td>
# </tr>
#
# <tr>
# <td>unique_app_category_visits</td>
# <td> The number of unique mini-app categories visited</td>
# </tr>
#
# <tr>
# <td>year_month</td>
# <td> The calendar month and year for the training features</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# 1. See attached dataset for you training
#     - Link to market specific teams channel data source
#
# 2. Validation/Out of time dataset will be shared later
#     - Link to market specific teams channel data source

# %% [markdown]
# # Research Questions
#
# - What factors are most predictive of whether or not someone will use VodaPay the following month, and how can these factors be used to improve user engagement?

# %% [markdown]
# # Methodology
#
# ![image.png](attachment:image.png)

# %%
# 1.Data Cleaning

# %%
# 2. Data Exploration

# %%
# 3. Featuring Engineering

# %%
# 4. Predictive Modeling

# %%
# 5. Data Visualisation

# %%
# 6. Insights and Summary
