# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('LTE_Layer Comparisons_20230627.xlsx')

# %%
df.head()
# Out:
#    ENODEB_ID  CI                    CellName Freq     BW CellOwner
# 0      27771  32  LTE_Dawn_Park_North_SGS_32   L9  10MHz       VOD  \
# 1      27771  31  LTE_Dawn_Park_North_SGS_31  L21  15MHz       VOD
# 2      27771   3   LTE_Dawn_Park_North_SGS_3  L18  10MHz       VOD
# 3      27771  22  LTE_Dawn_Park_North_SGS_22   L9  10MHz       VOD
# 4      27771  21  LTE_Dawn_Park_North_SGS_21  L21  15MHz       VOD
#
#    VF KPI 160 Cell Util (PRB)  Total DL Traffic Mbytes
# 0                      38.444                  2562.88  \
# 1                      97.564                 88805.24
# 2                      53.636                 19616.04
# 3                      50.028                 13808.44
# 4                     103.412                121241.64
#
#    Avg DL Cell Throughput Mbps   Max Connected Users  Avg TA Distance Km
# 0                          7.68                13.20                1.00  \
# 1                         18.52               112.24                1.60
# ...

# %%
df.isna().sum()
# Out:
# ENODEB_ID                       0
# CI                              0
# CellName                        0
# Freq                            0
# BW                              0
# CellOwner                       0
# VF KPI 160 Cell Util (PRB)      0
# Total DL Traffic Mbytes         0
# Avg DL Cell Throughput Mbps     0
# Max Connected Users             0
# Avg TA Distance Km              0
# Cell Unavail Rate               0
# Avg CQI                         0
# Avg SINR PUCCH dB               0
# Avg SINR PUSCH dB               0
# CA DL Traffic MB                0
# CA UL Traffic MB                0
# Avg DL CA User Throughput       0
# Avg UL CA User Throughput       0
# Avg DL Non-CA User Throughpu    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.CellOwner.unique()
# Out:
# array(['VOD', 'RAIN'], dtype=object)

# %%
sns.histplot(data=df, x='Freq') #amount of cells per frequency(both vodacom and RAIN)
# Out:
# <Axes: xlabel='Freq', ylabel='Count'>

# %%
df.columns #list the columns
# Out:
# Index(['ENODEB_ID', 'CI', 'CellName', 'Freq', 'BW', 'CellOwner',
#        'VF KPI 160 Cell Util (PRB)', 'Total DL Traffic Mbytes',
#        'Avg DL Cell Throughput Mbps ', 'Max Connected Users',
#        'Avg TA Distance Km', 'Cell Unavail Rate', 'Avg CQI',
#        'Avg SINR PUCCH dB', 'Avg SINR PUSCH dB', 'CA DL Traffic MB',
#        'CA UL Traffic MB', 'Avg DL CA User Throughput',
#        'Avg UL CA User Throughput', 'Avg DL Non-CA User Throughpu'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(' ', '_') #remove spaces on the column name and replace with underscore

# %%
df.head()
# Out:
#    ENODEB_ID  CI                    CellName Freq     BW CellOwner
# 0      27771  32  LTE_Dawn_Park_North_SGS_32   L9  10MHz       VOD  \
# 1      27771  31  LTE_Dawn_Park_North_SGS_31  L21  15MHz       VOD
# 2      27771   3   LTE_Dawn_Park_North_SGS_3  L18  10MHz       VOD
# 3      27771  22  LTE_Dawn_Park_North_SGS_22   L9  10MHz       VOD
# 4      27771  21  LTE_Dawn_Park_North_SGS_21  L21  15MHz       VOD
#
#    VF_KPI_160_Cell_Util_(PRB)  Total_DL_Traffic_Mbytes
# 0                      38.444                  2562.88  \
# 1                      97.564                 88805.24
# 2                      53.636                 19616.04
# 3                      50.028                 13808.44
# 4                     103.412                121241.64
#
#    Avg_DL_Cell_Throughput_Mbps_  Max_Connected_Users  Avg_TA_Distance_Km
# 0                          7.68                13.20                1.00  \
# 1                         18.52               112.24                1.60
# ...
